# %%
# !pip install streamlit

# %%
# -*- coding: utf-8 -*-
"""Advance task 5.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1aIkVg6ecodzYu6GaKECwduP7k8h1wLWH
"""
# Out:
# 'Advance task 5.ipynb\n\nAutomatically generated by Colab.\n\nOriginal file is located at\n    https://colab.research.google.com/drive/1aIkVg6ecodzYu6GaKECwduP7k8h1wLWH\n'

# %% [markdown]
# **Uploading data file on google colab's server**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70448621-684d-46d8-b699-810a362e8d02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70448621-684d-46d8-b699-810a362e8d02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **importing necessary libraries**

# %%
import pandas as pd
import streamlit as st

# %% [markdown]
# **Loading the data and making a couple of changes to have it cleaned.**

# %%
df = pd.read_csv('Global_Superstore2.csv', encoding='latin1')  # replace with your filename

# Clean & Convert
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Out:
# /tmp/ipython-input-7-3770763250.py:4: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
# /tmp/ipython-input-7-3770763250.py:5: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %% [markdown]
# **Streamlit Filters and Dashboard**

# %%
# Sidebar Filters
st.sidebar.title("🔎 Filter Options")
region = st.sidebar.multiselect("Select Region", options=df['Region'].unique(), default=df['Region'].unique())
category = st.sidebar.multiselect("Select Category", options=df['Category'].unique(), default=df['Category'].unique())
sub_category = st.sidebar.multiselect("Select Sub-Category", options=df['Sub-Category'].unique(), default=df['Sub-Category'].unique())

# Apply Filters
filtered_df = df[
    (df['Region'].isin(region)) &
    (df['Category'].isin(category)) &
    (df['Sub-Category'].isin(sub_category))
]

# Title
st.title("📊 Superstore Sales Dashboard")
# Out:
# 2025-07-14 17:19:36.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:19:36.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:19:36.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:19:36.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:19:36.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:19:37.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:19:37.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# **Creating KPIs**

# %%
# KPIs
total_sales = filtered_df['Sales'].sum()
total_profit = filtered_df['Profit'].sum()
top_customers = filtered_df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(5)

# KPI Display
col1, col2 = st.columns(2)
col1.metric("💰 Total Sales", f"${total_sales:,.0f}")
col2.metric("📈 Total Profit", f"${total_profit:,.0f}")

# Charts
st.subheader("🧑‍💼 Top 5 Customers by Sales")
st.bar_chart(top_customers)
# Out:
# 2025-07-14 17:20:01.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:20:01.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:20:01.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:20:01.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:20:01.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:20:01.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-14 17:20:01.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# **Problem Statement and Objective**

# %% [markdown]
# Develop an interactive dashboard for analyzing sales, profit, and segment-wise performance.

# %% [markdown]
# **Dataset Description and Loading**

# %% [markdown]
# 1. The Dataset was get from Kaggle and was loaded using import statement.
# 2. It has 24 Columns and 51291 Rows in total.
